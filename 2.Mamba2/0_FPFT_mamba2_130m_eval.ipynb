# %%
import os
import wandb
import transformers
import json
import random
import math
import pickle
import pandas as pd
import numpy as np
import re

from typing import Dict, List, Optional, Tuple, Union

from dataclasses import dataclass
from datasets import load_dataset, Dataset, DatasetDict, load_from_disk
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef
from sklearn.model_selection import train_test_split

from transformers import Trainer, AutoTokenizer, Mamba2ForCausalLM, TrainingArguments, DataCollatorWithPadding, Mamba2Config, GenerationMixin, DataCollatorForMultipleChoice, DataCollatorForLanguageModeling
from transformers.models.mamba2.modeling_mamba2 import Mamba2PreTrainedModel, Mamba2Model, Mamba2Cache, Mamba2CausalLMOutput
from transformers.utils import add_start_docstrings, add_start_docstrings_to_model_forward, logging, replace_return_docstrings, add_code_sample_docstrings
import evaluate

from peft import PeftModel, LoraConfig, get_peft_model
import peft.tuners.lora.layer as pl

import torch
from torch import nn
import torch.nn.functional as F
from torch.nn.modules.loss import CrossEntropyLoss

import pennylane as qml

from trl import SFTTrainer

from tqdm import tqdm
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence

from tqdm.notebook import tqdm
import time
from IPython.display import clear_output

_CHECKPOINT_FOR_DOC = "mistralai/mamba-codestral-7B-v0.1"
_CONFIG_FOR_DOC = "Mamba2Config"

# %%
# Take in the model you want to train
model_name = "mamba2_cp/0_iot_fpft_mamba2_130m"

tokenizer_model_name="AntonV/mamba2-130m-hf"

output_file = os.path.join(
    r"output", "0_iot_fpft_mamba2_130m_result.json"
)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" #enforce padding side left

# %%
CACHE_PATH = "iot_datasets/iot_resource_allocation_hf_dataset"
ds_dict = load_from_disk(CACHE_PATH)

# %%
iot_test_hf_dataset = Dataset.from_list(ds_dict["test"])
print(iot_test_hf_dataset[0])
# Out:
# {'text': '{"Timestamp": "2024-03-25 14:13:20", "Device_ID": "D2", "Temp": "32°C", "Humidity": "47%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 30, "Memory_Usage(MB)": 3059, "Network_Latency(ms)": 33, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 60, "Predicted_Resource_Allocation(%)": 55}\n###\nPredict the Actual Resource Allocation(%)', 'label': '59'}

# %%
def length_only(example):
    ids = tokenizer(example["text"], add_special_tokens=True,
                    padding=False, truncation=False).input_ids
    return {"seq_len": len(ids)}

train_with_len = ds_dict["test"].map(length_only)
MAX_LEN = int(np.max(train_with_len["seq_len"]))
print("Raw longest length:", MAX_LEN)

MAX_LEN = min(MAX_LEN, tokenizer.model_max_length)           
print("Effective MAX_LEN:", MAX_LEN)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Raw longest length: 141
# Effective MAX_LEN: 141

# %%
model = Mamba2ForCausalLM.from_pretrained(
    model_name, 
    device_map="cuda",
    )
print(model)
# Out:
# Mamba2ForCausalLM(
#   (backbone): Mamba2Model(
#     (embeddings): Embedding(50277, 768)
#     (layers): ModuleList(
#       (0-23): 24 x Mamba2Block(
#         (norm): Mamba2RMSNorm()
#         (mixer): Mamba2Mixer(
#           (act): SiLU()
#           (conv1d): Conv1d(1792, 1792, kernel_size=(4,), stride=(1,), padding=(3,), groups=1792)
#           (in_proj): Linear(in_features=768, out_features=3352, bias=False)
#           (norm): MambaRMSNormGated()
#           (out_proj): Linear(in_features=1536, out_features=768, bias=False)
#         )
#       )
#     )
#     (norm_f): Mamba2RMSNorm()
#   )
#   (lm_head): Linear(in_features=768, out_features=50277, bias=False)
# )

# %%
def run_mamba(model, context):

    text = f"{context}"
    # print(text)
    # input_ids = torch.LongTensor([tokenizer.encode(text)]).cuda()
    input_ids = tokenizer.encode(text, return_tensors="pt").cuda()
    # print(input_ids)

    attention_mask = torch.ones_like(input_ids).cuda()

    # print("max_length", input_ids.shape[1])

    out = model.generate(
        input_ids=input_ids,
        attention_mask=attention_mask,
        max_length=input_ids.shape[1]+10, #max_length_in_dataset
        # max_length=max_length_in_dataset,
        # max_new_tokens=max_length_in_dataset,
        eos_token_id=tokenizer.eos_token_id,
    )

    # print(out)
    decoded = tokenizer.batch_decode(out)[0]
    # print("="*80)
    # print(decoded)

    # out returns the whole sequence plus the original
    cleaned = decoded.replace(text, "")
    # cleaned = decoded[len(text):]
    cleaned = cleaned.replace("<|endoftext|>", "")

    # the model will just keep generating, so only grab the first one
    cleaned = cleaned.split("\n\n")[0].strip()
    lines = cleaned.splitlines()
    if lines:
        cleaned = lines[0].strip()

    # print(answer)
    return cleaned

# %%
context="{\"Timestamp\": \"2024-03-25 12:00:00\", \"Device_ID\": \"D14\", \"Temp\": \"32°C\", \"Humidity\": \"72%\", \"Workload_Type\": \"Data Analytics\", \"Processing_Tier\": \"Device\", \"CPU_Usage(%)\": 24, \"Memory_Usage(MB)\": 2276, \"Network_Latency(ms)\": 29, \"Network_Jitter(ms)\": 8, \"Task_Execution_Time(ms)\": 189, \Predicted_Resource_Allocation(%)\": 54}\n###\nPredict the Actual Resource Allocation(%)"
print(run_mamba(model, context=context))
# Out:
# 51

# %%
def write_results(results, output_file):
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

results = []
num_correct = 0  


start_time_total = time.time()


all_data = iot_test_hf_dataset

total_qs = len(all_data)

pbar = tqdm(total=total_qs, desc="Processing Questions: 1/{}".format(total_qs), dynamic_ncols=True)

for i, data in enumerate(all_data):
    start_time = time.time()

    pbar.set_description(f"Processing Questions: {i+1}/{total_qs}")

    text = data["text"]
    y_true = float(data["label"])  

    guess = run_mamba(model, text)  
    elapsed_time = time.time() - start_time

    try:
        pred_value = float(re.findall(r"[-+]?\d*\.\d+|\d+", guess)[-1])
    except (IndexError, ValueError):
        pred_value = np.nan

    is_correct = abs(pred_value - y_true) <= 3
    if is_correct:
        num_correct += 1

    tqdm.write(f"\nQuestion {i+1}/{total_qs}")
    tqdm.write(f"Context: {text}")
    tqdm.write(f"y_true: {y_true}")
    tqdm.write(f"pred: {pred_value}")
    if is_correct:
        tqdm.write("✅ Correct")
    else:
        tqdm.write("❌ Incorrect")
    tqdm.write(f"Time taken: {elapsed_time:.2f}s")
    tqdm.write("=" * 80)

    result = {
        "idx": i,
        "question": text,
        "context": context,
        "answer": y_true,
        "guess": pred_value,
        "is_correct": is_correct,
        "time": elapsed_time,
    }
    results.append(result)

    if len(results) % 20 == 0:
        write_results(results, output_file)

    if (i + 1) % 100 == 0:
        accuracy = num_correct / (i + 1) * 100
        tqdm.write(f"Current progress: {i+1}/{total_qs}, Accuracy: {accuracy:.2f}%")
        tqdm.write("=" * 80)
        pbar.set_postfix({"Accuracy": f"{accuracy:.2f}%", "Time/Question": f"{elapsed_time:.2f}s"})

    pbar.update(1)

pbar.close()

total_runtime = time.time() - start_time_total
hours = total_runtime / 3600


accuracy = num_correct / total_qs * 100
summary = {
    "total_questions": total_qs,
    "correct_answers": num_correct,
    "accuracy": accuracy,
    "run_time": hours,
}
results.append(summary)

write_results(results, output_file)

tqdm.write(f"Number of correct answers: {num_correct}, Total questions: {total_qs}, Accuracy rate: {accuracy:.2f}%, Total runtime: {total_runtime:.2f}s ({hours:.2f} hours)")
# Out:
# Processing Questions: 1/200:   0%|                                                                     | 0/200…
# Question 1/200
# Context: {"Timestamp": "2024-03-25 14:13:20", "Device_ID": "D2", "Temp": "32°C", "Humidity": "47%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 30, "Memory_Usage(MB)": 3059, "Network_Latency(ms)": 33, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 60, "Predicted_Resource_Allocation(%)": 55}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 59.0
# pred: 79.0
# ❌ Incorrect
# Time taken: 0.11s
# ================================================================================
#
# Question 2/200
# Context: {"Timestamp": "2024-03-25 14:13:30", "Device_ID": "D19", "Temp": "36°C", "Humidity": "48%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 43, "Memory_Usage(MB)": 5126, "Network_Latency(ms)": 43, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 72, "Predicted_Resource_Allocation(%)": 88}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 92.0
# pred: 90.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 3/200
# Context: {"Timestamp": "2024-03-25 14:13:40", "Device_ID": "D11", "Temp": "22°C", "Humidity": "54%", "Workload_Type": "Video Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 50, "Memory_Usage(MB)": 7380, "Network_Latency(ms)": 8, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 232, "Predicted_Resource_Allocation(%)": 84}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 87.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 4/200
# Context: {"Timestamp": "2024-03-25 14:13:50", "Device_ID": "D5", "Temp": "25°C", "Humidity": "54%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 28, "Memory_Usage(MB)": 5833, "Network_Latency(ms)": 10, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 184, "Predicted_Resource_Allocation(%)": 61}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 59.0
# pred: 59.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 5/200
# Context: {"Timestamp": "2024-03-25 14:14:00", "Device_ID": "D15", "Temp": "25°C", "Humidity": "79%", "Workload_Type": "Network Traffic", "Processing_Tier": "Device", "CPU_Usage(%)": 65, "Memory_Usage(MB)": 7233, "Network_Latency(ms)": 34, "Network_Jitter(ms)": 5, "Task_Execution_Time(ms)": 166, "Predicted_Resource_Allocation(%)": 67}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 66.0
# pred: 70.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 6/200
# Context: {"Timestamp": "2024-03-25 14:14:10", "Device_ID": "D2", "Temp": "30°C", "Humidity": "56%", "Workload_Type": "Image Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 86, "Memory_Usage(MB)": 7843, "Network_Latency(ms)": 38, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 223, "Predicted_Resource_Allocation(%)": 87}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 88.0
# pred: 88.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 7/200
# Context: {"Timestamp": "2024-03-25 14:14:20", "Device_ID": "D1", "Temp": "34°C", "Humidity": "46%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 63, "Memory_Usage(MB)": 1355, "Network_Latency(ms)": 19, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 73, "Predicted_Resource_Allocation(%)": 52}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 54.0
# pred: 51.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 8/200
# Context: {"Timestamp": "2024-03-25 14:14:30", "Device_ID": "D12", "Temp": "39°C", "Humidity": "52%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 50, "Memory_Usage(MB)": 3359, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 182, "Predicted_Resource_Allocation(%)": 54}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 57.0
# pred: 49.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 9/200
# Context: {"Timestamp": "2024-03-25 14:14:40", "Device_ID": "D6", "Temp": "39°C", "Humidity": "39%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 41, "Memory_Usage(MB)": 7455, "Network_Latency(ms)": 42, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 82, "Predicted_Resource_Allocation(%)": 52}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 56.0
# pred: 52.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 10/200
# Context: {"Timestamp": "2024-03-25 14:14:50", "Device_ID": "D11", "Temp": "28°C", "Humidity": "66%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 20, "Memory_Usage(MB)": 6570, "Network_Latency(ms)": 43, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 217, "Predicted_Resource_Allocation(%)": 79}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 76.0
# pred: 75.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 11/200
# Context: {"Timestamp": "2024-03-25 14:15:00", "Device_ID": "D17", "Temp": "22°C", "Humidity": "70%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 55, "Memory_Usage(MB)": 2297, "Network_Latency(ms)": 25, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 256, "Predicted_Resource_Allocation(%)": 69}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 72.0
# pred: 71.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 12/200
# Context: {"Timestamp": "2024-03-25 14:15:10", "Device_ID": "D12", "Temp": "34°C", "Humidity": "34%", "Workload_Type": "Video Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 72, "Memory_Usage(MB)": 4321, "Network_Latency(ms)": 10, "Network_Jitter(ms)": 5, "Task_Execution_Time(ms)": 214, "Predicted_Resource_Allocation(%)": 85}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 85.0
# pred: 88.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 13/200
# Context: {"Timestamp": "2024-03-25 14:15:20", "Device_ID": "D17", "Temp": "24°C", "Humidity": "79%", "Workload_Type": "Network Traffic", "Processing_Tier": "Fog", "CPU_Usage(%)": 14, "Memory_Usage(MB)": 8076, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 150, "Predicted_Resource_Allocation(%)": 62}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 61.0
# pred: 60.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 14/200
# Context: {"Timestamp": "2024-03-25 14:15:30", "Device_ID": "D20", "Temp": "36°C", "Humidity": "31%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 43, "Memory_Usage(MB)": 3158, "Network_Latency(ms)": 37, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 251, "Predicted_Resource_Allocation(%)": 81}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 84.0
# pred: 80.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 15/200
# Context: {"Timestamp": "2024-03-25 14:15:40", "Device_ID": "D15", "Temp": "32°C", "Humidity": "68%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 28, "Memory_Usage(MB)": 3676, "Network_Latency(ms)": 34, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 245, "Predicted_Resource_Allocation(%)": 73}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 74.0
# pred: 72.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 16/200
# Context: {"Timestamp": "2024-03-25 14:15:50", "Device_ID": "D16", "Temp": "39°C", "Humidity": "75%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 66, "Memory_Usage(MB)": 3347, "Network_Latency(ms)": 45, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 104, "Predicted_Resource_Allocation(%)": 60}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 55.0
# pred: 55.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 17/200
# Context: {"Timestamp": "2024-03-25 14:16:00", "Device_ID": "D9", "Temp": "29°C", "Humidity": "65%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 76, "Memory_Usage(MB)": 790, "Network_Latency(ms)": 32, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 218, "Predicted_Resource_Allocation(%)": 79}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 75.0
# pred: 75.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 18/200
# Context: {"Timestamp": "2024-03-25 14:16:10", "Device_ID": "D15", "Temp": "38°C", "Humidity": "68%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 63, "Memory_Usage(MB)": 3430, "Network_Latency(ms)": 24, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 56, "Predicted_Resource_Allocation(%)": 67}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 63.0
# pred: 70.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 19/200
# Context: {"Timestamp": "2024-03-25 14:16:20", "Device_ID": "D8", "Temp": "31°C", "Humidity": "42%", "Workload_Type": "Data Analytics", "Processing_Tier": "Edge", "CPU_Usage(%)": 73, "Memory_Usage(MB)": 2853, "Network_Latency(ms)": 29, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 144, "Predicted_Resource_Allocation(%)": 83}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 81.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 20/200
# Context: {"Timestamp": "2024-03-25 14:16:30", "Device_ID": "D14", "Temp": "25°C", "Humidity": "63%", "Workload_Type": "Video Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 80, "Memory_Usage(MB)": 7144, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 160, "Predicted_Resource_Allocation(%)": 89}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 91.0
# pred: 93.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 21/200
# Context: {"Timestamp": "2024-03-25 14:16:40", "Device_ID": "D6", "Temp": "21°C", "Humidity": "56%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 10, "Memory_Usage(MB)": 6902, "Network_Latency(ms)": 49, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 64, "Predicted_Resource_Allocation(%)": 51}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 46.0
# pred: 46.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 22/200
# Context: {"Timestamp": "2024-03-25 14:16:50", "Device_ID": "D18", "Temp": "24°C", "Humidity": "67%", "Workload_Type": "Image Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 72, "Memory_Usage(MB)": 7595, "Network_Latency(ms)": 45, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 106, "Predicted_Resource_Allocation(%)": 86}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 90.0
# pred: 84.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 23/200
# Context: {"Timestamp": "2024-03-25 14:17:00", "Device_ID": "D6", "Temp": "31°C", "Humidity": "54%", "Workload_Type": "Image Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 25, "Memory_Usage(MB)": 7818, "Network_Latency(ms)": 30, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 231, "Predicted_Resource_Allocation(%)": 54}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 52.0
# pred: 54.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 24/200
# Context: {"Timestamp": "2024-03-25 14:17:10", "Device_ID": "D9", "Temp": "23°C", "Humidity": "41%", "Workload_Type": "Data Analytics", "Processing_Tier": "Edge", "CPU_Usage(%)": 26, "Memory_Usage(MB)": 3066, "Network_Latency(ms)": 34, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 189, "Predicted_Resource_Allocation(%)": 55}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 55.0
# pred: 56.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 25/200
# Context: {"Timestamp": "2024-03-25 14:17:20", "Device_ID": "D2", "Temp": "38°C", "Humidity": "54%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 58, "Memory_Usage(MB)": 7681, "Network_Latency(ms)": 30, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 57, "Predicted_Resource_Allocation(%)": 75}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 74.0
# pred: 72.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 26/200
# Context: {"Timestamp": "2024-03-25 14:17:30", "Device_ID": "D8", "Temp": "32°C", "Humidity": "78%", "Workload_Type": "Network Traffic", "Processing_Tier": "Cloud", "CPU_Usage(%)": 82, "Memory_Usage(MB)": 7490, "Network_Latency(ms)": 27, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 177, "Predicted_Resource_Allocation(%)": 52}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 49.0
# pred: 52.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 27/200
# Context: {"Timestamp": "2024-03-25 14:17:40", "Device_ID": "D15", "Temp": "35°C", "Humidity": "58%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 14, "Memory_Usage(MB)": 2604, "Network_Latency(ms)": 14, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 205, "Predicted_Resource_Allocation(%)": 53}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 50.0
# pred: 51.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 28/200
# Context: {"Timestamp": "2024-03-25 14:17:50", "Device_ID": "D2", "Temp": "24°C", "Humidity": "57%", "Workload_Type": "Video Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 35, "Memory_Usage(MB)": 640, "Network_Latency(ms)": 41, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 107, "Predicted_Resource_Allocation(%)": 86}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 83.0
# pred: 84.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 29/200
# Context: {"Timestamp": "2024-03-25 14:18:00", "Device_ID": "D5", "Temp": "23°C", "Humidity": "41%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 82, "Memory_Usage(MB)": 7569, "Network_Latency(ms)": 46, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 93, "Predicted_Resource_Allocation(%)": 87}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 83.0
# pred: 88.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 30/200
# Context: {"Timestamp": "2024-03-25 14:18:10", "Device_ID": "D13", "Temp": "31°C", "Humidity": "57%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 37, "Memory_Usage(MB)": 1688, "Network_Latency(ms)": 29, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 103, "Predicted_Resource_Allocation(%)": 88}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 88.0
# pred: 91.0
# ✅ Correct
# Time taken: 0.05s
# ================================================================================
#
# Question 31/200
# Context: {"Timestamp": "2024-03-25 14:18:20", "Device_ID": "D4", "Temp": "36°C", "Humidity": "48%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 29, "Memory_Usage(MB)": 1887, "Network_Latency(ms)": 9, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 272, "Predicted_Resource_Allocation(%)": 63}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 66.0
# pred: 62.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 32/200
# Context: {"Timestamp": "2024-03-25 14:18:30", "Device_ID": "D19", "Temp": "34°C", "Humidity": "53%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 20, "Memory_Usage(MB)": 5379, "Network_Latency(ms)": 32, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 287, "Predicted_Resource_Allocation(%)": 54}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 56.0
# pred: 51.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 33/200
# Context: {"Timestamp": "2024-03-25 14:18:40", "Device_ID": "D20", "Temp": "23°C", "Humidity": "53%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 52, "Memory_Usage(MB)": 5239, "Network_Latency(ms)": 5, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 156, "Predicted_Resource_Allocation(%)": 88}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 91.0
# pred: 89.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 34/200
# Context: {"Timestamp": "2024-03-25 14:18:50", "Device_ID": "D15", "Temp": "35°C", "Humidity": "49%", "Workload_Type": "Network Traffic", "Processing_Tier": "Device", "CPU_Usage(%)": 79, "Memory_Usage(MB)": 7050, "Network_Latency(ms)": 41, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 110, "Predicted_Resource_Allocation(%)": 82}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 80.0
# pred: 79.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 35/200
# Context: {"Timestamp": "2024-03-25 14:19:00", "Device_ID": "D3", "Temp": "25°C", "Humidity": "68%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 61, "Memory_Usage(MB)": 1517, "Network_Latency(ms)": 28, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 257, "Predicted_Resource_Allocation(%)": 75}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 74.0
# pred: 76.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 36/200
# Context: {"Timestamp": "2024-03-25 14:19:10", "Device_ID": "D17", "Temp": "21°C", "Humidity": "72%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 79, "Memory_Usage(MB)": 4342, "Network_Latency(ms)": 10, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 296, "Predicted_Resource_Allocation(%)": 72}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 67.0
# pred: 69.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 37/200
# Context: {"Timestamp": "2024-03-25 14:19:20", "Device_ID": "D18", "Temp": "25°C", "Humidity": "71%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 22, "Memory_Usage(MB)": 7198, "Network_Latency(ms)": 36, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 77, "Predicted_Resource_Allocation(%)": 60}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 63.0
# pred: 63.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 38/200
# Context: {"Timestamp": "2024-03-25 14:19:30", "Device_ID": "D17", "Temp": "32°C", "Humidity": "59%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 32, "Memory_Usage(MB)": 555, "Network_Latency(ms)": 39, "Network_Jitter(ms)": 5, "Task_Execution_Time(ms)": 137, "Predicted_Resource_Allocation(%)": 67}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 65.0
# pred: 70.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 39/200
# Context: {"Timestamp": "2024-03-25 14:19:40", "Device_ID": "D11", "Temp": "25°C", "Humidity": "38%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 86, "Memory_Usage(MB)": 7135, "Network_Latency(ms)": 29, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 191, "Predicted_Resource_Allocation(%)": 88}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 90.0
# pred: 91.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 40/200
# Context: {"Timestamp": "2024-03-25 14:19:50", "Device_ID": "D8", "Temp": "27°C", "Humidity": "39%", "Workload_Type": "Network Traffic", "Processing_Tier": "Device", "CPU_Usage(%)": 30, "Memory_Usage(MB)": 6818, "Network_Latency(ms)": 40, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 181, "Predicted_Resource_Allocation(%)": 50}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 52.0
# pred: 45.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 41/200
# Context: {"Timestamp": "2024-03-25 14:20:00", "Device_ID": "D14", "Temp": "28°C", "Humidity": "59%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 33, "Memory_Usage(MB)": 7175, "Network_Latency(ms)": 13, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 101, "Predicted_Resource_Allocation(%)": 76}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 80.0
# pred: 71.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 42/200
# Context: {"Timestamp": "2024-03-25 14:20:10", "Device_ID": "D11", "Temp": "38°C", "Humidity": "73%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 54, "Memory_Usage(MB)": 3292, "Network_Latency(ms)": 26, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 253, "Predicted_Resource_Allocation(%)": 72}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 73.0
# pred: 67.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 43/200
# Context: {"Timestamp": "2024-03-25 14:20:20", "Device_ID": "D20", "Temp": "20°C", "Humidity": "35%", "Workload_Type": "Video Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 29, "Memory_Usage(MB)": 6978, "Network_Latency(ms)": 46, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 299, "Predicted_Resource_Allocation(%)": 54}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 51.0
# pred: 51.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 44/200
# Context: {"Timestamp": "2024-03-25 14:20:30", "Device_ID": "D13", "Temp": "28°C", "Humidity": "70%", "Workload_Type": "Network Traffic", "Processing_Tier": "Device", "CPU_Usage(%)": 59, "Memory_Usage(MB)": 934, "Network_Latency(ms)": 48, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 271, "Predicted_Resource_Allocation(%)": 65}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 60.0
# pred: 69.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 45/200
# Context: {"Timestamp": "2024-03-25 14:20:40", "Device_ID": "D17", "Temp": "34°C", "Humidity": "68%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 24, "Memory_Usage(MB)": 5842, "Network_Latency(ms)": 45, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 248, "Predicted_Resource_Allocation(%)": 60}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 61.0
# pred: 61.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 46/200
# Context: {"Timestamp": "2024-03-25 14:20:50", "Device_ID": "D8", "Temp": "22°C", "Humidity": "74%", "Workload_Type": "Data Analytics", "Processing_Tier": "Cloud", "CPU_Usage(%)": 65, "Memory_Usage(MB)": 6135, "Network_Latency(ms)": 35, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 51, "Predicted_Resource_Allocation(%)": 71}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 67.0
# pred: 72.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 47/200
# Context: {"Timestamp": "2024-03-25 14:21:00", "Device_ID": "D1", "Temp": "24°C", "Humidity": "54%", "Workload_Type": "Image Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 43, "Memory_Usage(MB)": 4255, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 120, "Predicted_Resource_Allocation(%)": 86}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 89.0
# pred: 84.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 48/200
# Context: {"Timestamp": "2024-03-25 14:21:10", "Device_ID": "D19", "Temp": "31°C", "Humidity": "51%", "Workload_Type": "Video Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 30, "Memory_Usage(MB)": 3756, "Network_Latency(ms)": 22, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 109, "Predicted_Resource_Allocation(%)": 64}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 64.0
# pred: 62.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 49/200
# Context: {"Timestamp": "2024-03-25 14:21:20", "Device_ID": "D8", "Temp": "33°C", "Humidity": "50%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 18, "Memory_Usage(MB)": 1334, "Network_Latency(ms)": 45, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 288, "Predicted_Resource_Allocation(%)": 56}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 56.0
# pred: 57.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 50/200
# Context: {"Timestamp": "2024-03-25 14:21:30", "Device_ID": "D12", "Temp": "24°C", "Humidity": "38%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 18, "Memory_Usage(MB)": 4966, "Network_Latency(ms)": 24, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 97, "Predicted_Resource_Allocation(%)": 85}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 81.0
# pred: 87.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 51/200
# Context: {"Timestamp": "2024-03-25 14:21:40", "Device_ID": "D6", "Temp": "39°C", "Humidity": "32%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 68, "Memory_Usage(MB)": 5327, "Network_Latency(ms)": 33, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 210, "Predicted_Resource_Allocation(%)": 74}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 70.0
# pred: 75.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 52/200
# Context: {"Timestamp": "2024-03-25 14:21:50", "Device_ID": "D8", "Temp": "30°C", "Humidity": "52%", "Workload_Type": "Video Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 27, "Memory_Usage(MB)": 3042, "Network_Latency(ms)": 40, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 290, "Predicted_Resource_Allocation(%)": 56}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 58.0
# pred: 59.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 53/200
# Context: {"Timestamp": "2024-03-25 14:22:00", "Device_ID": "D20", "Temp": "37°C", "Humidity": "53%", "Workload_Type": "Network Traffic", "Processing_Tier": "Device", "CPU_Usage(%)": 46, "Memory_Usage(MB)": 3734, "Network_Latency(ms)": 16, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 53, "Predicted_Resource_Allocation(%)": 69}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 66.0
# pred: 64.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 54/200
# Context: {"Timestamp": "2024-03-25 14:22:10", "Device_ID": "D6", "Temp": "25°C", "Humidity": "64%", "Workload_Type": "Video Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 66, "Memory_Usage(MB)": 7082, "Network_Latency(ms)": 38, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 83, "Predicted_Resource_Allocation(%)": 51}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 51.0
# pred: 53.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 55/200
# Context: {"Timestamp": "2024-03-25 14:22:20", "Device_ID": "D14", "Temp": "23°C", "Humidity": "50%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 55, "Memory_Usage(MB)": 2963, "Network_Latency(ms)": 27, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 213, "Predicted_Resource_Allocation(%)": 81}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 78.0
# pred: 78.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 56/200
# Context: {"Timestamp": "2024-03-25 14:22:30", "Device_ID": "D7", "Temp": "34°C", "Humidity": "53%", "Workload_Type": "Data Analytics", "Processing_Tier": "Cloud", "CPU_Usage(%)": 77, "Memory_Usage(MB)": 6175, "Network_Latency(ms)": 15, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 197, "Predicted_Resource_Allocation(%)": 86}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 84.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 57/200
# Context: {"Timestamp": "2024-03-25 14:22:40", "Device_ID": "D10", "Temp": "25°C", "Humidity": "69%", "Workload_Type": "Network Traffic", "Processing_Tier": "Fog", "CPU_Usage(%)": 72, "Memory_Usage(MB)": 3294, "Network_Latency(ms)": 38, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 125, "Predicted_Resource_Allocation(%)": 87}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 90.0
# pred: 88.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 58/200
# Context: {"Timestamp": "2024-03-25 14:22:50", "Device_ID": "D20", "Temp": "26°C", "Humidity": "34%", "Workload_Type": "Video Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 65, "Memory_Usage(MB)": 3203, "Network_Latency(ms)": 14, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 192, "Predicted_Resource_Allocation(%)": 80}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 80.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 59/200
# Context: {"Timestamp": "2024-03-25 14:23:00", "Device_ID": "D19", "Temp": "34°C", "Humidity": "46%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 71, "Memory_Usage(MB)": 3915, "Network_Latency(ms)": 8, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 94, "Predicted_Resource_Allocation(%)": 72}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 74.0
# pred: 67.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 60/200
# Context: {"Timestamp": "2024-03-25 14:23:10", "Device_ID": "D6", "Temp": "29°C", "Humidity": "65%", "Workload_Type": "Video Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 27, "Memory_Usage(MB)": 5226, "Network_Latency(ms)": 11, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 214, "Predicted_Resource_Allocation(%)": 50}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 52.0
# pred: 45.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 61/200
# Context: {"Timestamp": "2024-03-25 14:23:20", "Device_ID": "D6", "Temp": "30°C", "Humidity": "50%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 19, "Memory_Usage(MB)": 3421, "Network_Latency(ms)": 5, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 112, "Predicted_Resource_Allocation(%)": 80}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 79.0
# pred: 78.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 62/200
# Context: {"Timestamp": "2024-03-25 14:23:30", "Device_ID": "D18", "Temp": "25°C", "Humidity": "61%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 64, "Memory_Usage(MB)": 1515, "Network_Latency(ms)": 28, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 260, "Predicted_Resource_Allocation(%)": 68}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 65.0
# pred: 69.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 63/200
# Context: {"Timestamp": "2024-03-25 14:23:40", "Device_ID": "D7", "Temp": "29°C", "Humidity": "57%", "Workload_Type": "Image Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 40, "Memory_Usage(MB)": 2020, "Network_Latency(ms)": 32, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 86, "Predicted_Resource_Allocation(%)": 80}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 80.0
# pred: 78.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 64/200
# Context: {"Timestamp": "2024-03-25 14:23:50", "Device_ID": "D12", "Temp": "25°C", "Humidity": "37%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 75, "Memory_Usage(MB)": 2541, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 262, "Predicted_Resource_Allocation(%)": 71}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 68.0
# pred: 72.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 65/200
# Context: {"Timestamp": "2024-03-25 14:24:00", "Device_ID": "D6", "Temp": "27°C", "Humidity": "52%", "Workload_Type": "Image Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 36, "Memory_Usage(MB)": 2022, "Network_Latency(ms)": 44, "Network_Jitter(ms)": 5, "Task_Execution_Time(ms)": 195, "Predicted_Resource_Allocation(%)": 76}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 72.0
# pred: 75.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 66/200
# Context: {"Timestamp": "2024-03-25 14:24:10", "Device_ID": "D7", "Temp": "23°C", "Humidity": "59%", "Workload_Type": "Data Analytics", "Processing_Tier": "Cloud", "CPU_Usage(%)": 18, "Memory_Usage(MB)": 6035, "Network_Latency(ms)": 49, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 192, "Predicted_Resource_Allocation(%)": 79}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 80.0
# pred: 80.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 67/200
# Context: {"Timestamp": "2024-03-25 14:24:20", "Device_ID": "D11", "Temp": "24°C", "Humidity": "62%", "Workload_Type": "Data Analytics", "Processing_Tier": "Edge", "CPU_Usage(%)": 47, "Memory_Usage(MB)": 3877, "Network_Latency(ms)": 41, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 149, "Predicted_Resource_Allocation(%)": 82}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 83.0
# pred: 79.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 68/200
# Context: {"Timestamp": "2024-03-25 14:24:30", "Device_ID": "D5", "Temp": "29°C", "Humidity": "60%", "Workload_Type": "Network Traffic", "Processing_Tier": "Fog", "CPU_Usage(%)": 21, "Memory_Usage(MB)": 4993, "Network_Latency(ms)": 38, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 215, "Predicted_Resource_Allocation(%)": 76}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 77.0
# pred: 71.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 69/200
# Context: {"Timestamp": "2024-03-25 14:24:40", "Device_ID": "D20", "Temp": "35°C", "Humidity": "33%", "Workload_Type": "Video Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 47, "Memory_Usage(MB)": 7308, "Network_Latency(ms)": 47, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 271, "Predicted_Resource_Allocation(%)": 84}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 79.0
# pred: 81.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 70/200
# Context: {"Timestamp": "2024-03-25 14:24:50", "Device_ID": "D15", "Temp": "39°C", "Humidity": "67%", "Workload_Type": "Image Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 43, "Memory_Usage(MB)": 2448, "Network_Latency(ms)": 48, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 287, "Predicted_Resource_Allocation(%)": 83}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 79.0
# pred: 83.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 71/200
# Context: {"Timestamp": "2024-03-25 14:25:00", "Device_ID": "D1", "Temp": "28°C", "Humidity": "59%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 39, "Memory_Usage(MB)": 5501, "Network_Latency(ms)": 33, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 146, "Predicted_Resource_Allocation(%)": 55}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 59.0
# pred: 57.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 72/200
# Context: {"Timestamp": "2024-03-25 14:25:10", "Device_ID": "D14", "Temp": "26°C", "Humidity": "64%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 73, "Memory_Usage(MB)": 617, "Network_Latency(ms)": 37, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 84, "Predicted_Resource_Allocation(%)": 77}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 74.0
# pred: 73.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 73/200
# Context: {"Timestamp": "2024-03-25 14:25:20", "Device_ID": "D5", "Temp": "38°C", "Humidity": "65%", "Workload_Type": "Network Traffic", "Processing_Tier": "Device", "CPU_Usage(%)": 10, "Memory_Usage(MB)": 8013, "Network_Latency(ms)": 27, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 206, "Predicted_Resource_Allocation(%)": 80}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 78.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 74/200
# Context: {"Timestamp": "2024-03-25 14:25:30", "Device_ID": "D5", "Temp": "29°C", "Humidity": "44%", "Workload_Type": "Video Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 76, "Memory_Usage(MB)": 5268, "Network_Latency(ms)": 14, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 210, "Predicted_Resource_Allocation(%)": 87}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 90.0
# pred: 82.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 75/200
# Context: {"Timestamp": "2024-03-25 14:25:40", "Device_ID": "D17", "Temp": "24°C", "Humidity": "35%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 23, "Memory_Usage(MB)": 6619, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 277, "Predicted_Resource_Allocation(%)": 50}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 46.0
# pred: 47.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 76/200
# Context: {"Timestamp": "2024-03-25 14:25:50", "Device_ID": "D12", "Temp": "36°C", "Humidity": "36%", "Workload_Type": "Video Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 84, "Memory_Usage(MB)": 6809, "Network_Latency(ms)": 33, "Network_Jitter(ms)": 5, "Task_Execution_Time(ms)": 271, "Predicted_Resource_Allocation(%)": 67}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 65.0
# pred: 67.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 77/200
# Context: {"Timestamp": "2024-03-25 14:26:00", "Device_ID": "D12", "Temp": "23°C", "Humidity": "62%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 43, "Memory_Usage(MB)": 3934, "Network_Latency(ms)": 25, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 281, "Predicted_Resource_Allocation(%)": 75}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 73.0
# pred: 76.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 78/200
# Context: {"Timestamp": "2024-03-25 14:26:10", "Device_ID": "D11", "Temp": "37°C", "Humidity": "61%", "Workload_Type": "Video Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 26, "Memory_Usage(MB)": 4896, "Network_Latency(ms)": 27, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 153, "Predicted_Resource_Allocation(%)": 87}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 91.0
# pred: 85.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 79/200
# Context: {"Timestamp": "2024-03-25 14:26:20", "Device_ID": "D11", "Temp": "39°C", "Humidity": "47%", "Workload_Type": "Data Analytics", "Processing_Tier": "Edge", "CPU_Usage(%)": 61, "Memory_Usage(MB)": 7742, "Network_Latency(ms)": 48, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 238, "Predicted_Resource_Allocation(%)": 82}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 85.0
# pred: 84.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 80/200
# Context: {"Timestamp": "2024-03-25 14:26:30", "Device_ID": "D19", "Temp": "25°C", "Humidity": "54%", "Workload_Type": "Video Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 87, "Memory_Usage(MB)": 7747, "Network_Latency(ms)": 19, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 146, "Predicted_Resource_Allocation(%)": 53}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 49.0
# pred: 54.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 81/200
# Context: {"Timestamp": "2024-03-25 14:26:40", "Device_ID": "D11", "Temp": "38°C", "Humidity": "49%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 34, "Memory_Usage(MB)": 1011, "Network_Latency(ms)": 29, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 186, "Predicted_Resource_Allocation(%)": 72}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 73.0
# pred: 67.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 82/200
# Context: {"Timestamp": "2024-03-25 14:26:50", "Device_ID": "D2", "Temp": "35°C", "Humidity": "36%", "Workload_Type": "Network Traffic", "Processing_Tier": "Fog", "CPU_Usage(%)": 42, "Memory_Usage(MB)": 1747, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 62, "Predicted_Resource_Allocation(%)": 83}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 83.0
# pred: 86.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 83/200
# Context: {"Timestamp": "2024-03-25 14:27:00", "Device_ID": "D10", "Temp": "24°C", "Humidity": "31%", "Workload_Type": "Data Analytics", "Processing_Tier": "Edge", "CPU_Usage(%)": 70, "Memory_Usage(MB)": 6951, "Network_Latency(ms)": 17, "Network_Jitter(ms)": 5, "Task_Execution_Time(ms)": 192, "Predicted_Resource_Allocation(%)": 63}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 63.0
# pred: 61.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 84/200
# Context: {"Timestamp": "2024-03-25 14:27:10", "Device_ID": "D9", "Temp": "27°C", "Humidity": "38%", "Workload_Type": "Video Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 14, "Memory_Usage(MB)": 7513, "Network_Latency(ms)": 48, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 210, "Predicted_Resource_Allocation(%)": 81}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 79.0
# pred: 80.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 85/200
# Context: {"Timestamp": "2024-03-25 14:27:20", "Device_ID": "D4", "Temp": "27°C", "Humidity": "72%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 11, "Memory_Usage(MB)": 3468, "Network_Latency(ms)": 17, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 172, "Predicted_Resource_Allocation(%)": 61}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 56.0
# pred: 57.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 86/200
# Context: {"Timestamp": "2024-03-25 14:27:30", "Device_ID": "D11", "Temp": "20°C", "Humidity": "54%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 69, "Memory_Usage(MB)": 870, "Network_Latency(ms)": 46, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 216, "Predicted_Resource_Allocation(%)": 71}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 73.0
# pred: 74.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 87/200
# Context: {"Timestamp": "2024-03-25 14:27:40", "Device_ID": "D17", "Temp": "31°C", "Humidity": "68%", "Workload_Type": "Video Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 45, "Memory_Usage(MB)": 3562, "Network_Latency(ms)": 13, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 199, "Predicted_Resource_Allocation(%)": 76}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 80.0
# pred: 75.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 88/200
# Context: {"Timestamp": "2024-03-25 14:27:50", "Device_ID": "D7", "Temp": "30°C", "Humidity": "56%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 21, "Memory_Usage(MB)": 4993, "Network_Latency(ms)": 38, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 185, "Predicted_Resource_Allocation(%)": 59}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 56.0
# pred: 59.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 89/200
# Context: {"Timestamp": "2024-03-25 14:28:00", "Device_ID": "D14", "Temp": "21°C", "Humidity": "34%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 34, "Memory_Usage(MB)": 5997, "Network_Latency(ms)": 44, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 221, "Predicted_Resource_Allocation(%)": 57}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 56.0
# pred: 58.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 90/200
# Context: {"Timestamp": "2024-03-25 14:28:10", "Device_ID": "D5", "Temp": "30°C", "Humidity": "41%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 47, "Memory_Usage(MB)": 2205, "Network_Latency(ms)": 33, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 68, "Predicted_Resource_Allocation(%)": 50}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 48.0
# pred: 49.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 91/200
# ...
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 59.0
# pred: 59.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 172/200
# Context: {"Timestamp": "2024-03-25 14:41:50", "Device_ID": "D18", "Temp": "22°C", "Humidity": "75%", "Workload_Type": "Image Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 45, "Memory_Usage(MB)": 5972, "Network_Latency(ms)": 13, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 122, "Predicted_Resource_Allocation(%)": 62}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 65.0
# pred: 59.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 173/200
# Context: {"Timestamp": "2024-03-25 14:42:00", "Device_ID": "D17", "Temp": "36°C", "Humidity": "47%", "Workload_Type": "Network Traffic", "Processing_Tier": "Edge", "CPU_Usage(%)": 84, "Memory_Usage(MB)": 1733, "Network_Latency(ms)": 15, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 260, "Predicted_Resource_Allocation(%)": 82}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 84.0
# pred: 79.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 174/200
# Context: {"Timestamp": "2024-03-25 14:42:10", "Device_ID": "D15", "Temp": "26°C", "Humidity": "72%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 45, "Memory_Usage(MB)": 966, "Network_Latency(ms)": 8, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 147, "Predicted_Resource_Allocation(%)": 51}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 49.0
# pred: 55.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 175/200
# Context: {"Timestamp": "2024-03-25 14:42:20", "Device_ID": "D15", "Temp": "35°C", "Humidity": "76%", "Workload_Type": "Network Traffic", "Processing_Tier": "Fog", "CPU_Usage(%)": 59, "Memory_Usage(MB)": 3164, "Network_Latency(ms)": 12, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 113, "Predicted_Resource_Allocation(%)": 72}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 73.0
# pred: 68.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 176/200
# Context: {"Timestamp": "2024-03-25 14:42:30", "Device_ID": "D15", "Temp": "39°C", "Humidity": "50%", "Workload_Type": "Image Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 24, "Memory_Usage(MB)": 4523, "Network_Latency(ms)": 27, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 162, "Predicted_Resource_Allocation(%)": 78}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 74.0
# pred: 77.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 177/200
# Context: {"Timestamp": "2024-03-25 14:42:40", "Device_ID": "D17", "Temp": "30°C", "Humidity": "42%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 77, "Memory_Usage(MB)": 4899, "Network_Latency(ms)": 16, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 231, "Predicted_Resource_Allocation(%)": 54}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 57.0
# pred: 49.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 178/200
# Context: {"Timestamp": "2024-03-25 14:42:50", "Device_ID": "D11", "Temp": "20°C", "Humidity": "74%", "Workload_Type": "Data Analytics", "Processing_Tier": "Fog", "CPU_Usage(%)": 67, "Memory_Usage(MB)": 3819, "Network_Latency(ms)": 16, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 227, "Predicted_Resource_Allocation(%)": 52}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 54.0
# pred: 52.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 179/200
# Context: {"Timestamp": "2024-03-25 14:43:00", "Device_ID": "D19", "Temp": "29°C", "Humidity": "58%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 67, "Memory_Usage(MB)": 4690, "Network_Latency(ms)": 12, "Network_Jitter(ms)": 7, "Task_Execution_Time(ms)": 148, "Predicted_Resource_Allocation(%)": 75}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 77.0
# pred: 76.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 180/200
# Context: {"Timestamp": "2024-03-25 14:43:10", "Device_ID": "D13", "Temp": "32°C", "Humidity": "47%", "Workload_Type": "Video Processing", "Processing_Tier": "Edge", "CPU_Usage(%)": 68, "Memory_Usage(MB)": 5023, "Network_Latency(ms)": 11, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 287, "Predicted_Resource_Allocation(%)": 87}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 89.0
# pred: 85.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 181/200
# Context: {"Timestamp": "2024-03-25 14:43:20", "Device_ID": "D8", "Temp": "39°C", "Humidity": "65%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 46, "Memory_Usage(MB)": 1902, "Network_Latency(ms)": 31, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 177, "Predicted_Resource_Allocation(%)": 50}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 54.0
# pred: 49.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 182/200
# Context: {"Timestamp": "2024-03-25 14:43:30", "Device_ID": "D10", "Temp": "29°C", "Humidity": "75%", "Workload_Type": "Data Analytics", "Processing_Tier": "Edge", "CPU_Usage(%)": 34, "Memory_Usage(MB)": 7516, "Network_Latency(ms)": 45, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 188, "Predicted_Resource_Allocation(%)": 88}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 91.0
# pred: 91.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 183/200
# Context: {"Timestamp": "2024-03-25 14:43:40", "Device_ID": "D8", "Temp": "23°C", "Humidity": "58%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 88, "Memory_Usage(MB)": 6658, "Network_Latency(ms)": 8, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 277, "Predicted_Resource_Allocation(%)": 79}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 76.0
# pred: 75.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 184/200
# Context: {"Timestamp": "2024-03-25 14:43:50", "Device_ID": "D16", "Temp": "28°C", "Humidity": "62%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 71, "Memory_Usage(MB)": 1343, "Network_Latency(ms)": 47, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 121, "Predicted_Resource_Allocation(%)": 70}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 70.0
# pred: 74.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 185/200
# Context: {"Timestamp": "2024-03-25 14:44:00", "Device_ID": "D16", "Temp": "21°C", "Humidity": "65%", "Workload_Type": "Video Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 26, "Memory_Usage(MB)": 2174, "Network_Latency(ms)": 21, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 170, "Predicted_Resource_Allocation(%)": 64}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 59.0
# pred: 62.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 186/200
# Context: {"Timestamp": "2024-03-25 14:44:10", "Device_ID": "D12", "Temp": "25°C", "Humidity": "54%", "Workload_Type": "Image Processing", "Processing_Tier": "Fog", "CPU_Usage(%)": 53, "Memory_Usage(MB)": 2249, "Network_Latency(ms)": 5, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 170, "Predicted_Resource_Allocation(%)": 63}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 60.0
# pred: 62.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 187/200
# Context: {"Timestamp": "2024-03-25 14:44:20", "Device_ID": "D3", "Temp": "30°C", "Humidity": "70%", "Workload_Type": "Data Analytics", "Processing_Tier": "Device", "CPU_Usage(%)": 81, "Memory_Usage(MB)": 1499, "Network_Latency(ms)": 9, "Network_Jitter(ms)": 5, "Task_Execution_Time(ms)": 124, "Predicted_Resource_Allocation(%)": 80}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 77.0
# pred: 78.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 188/200
# Context: {"Timestamp": "2024-03-25 14:44:30", "Device_ID": "D13", "Temp": "20°C", "Humidity": "54%", "Workload_Type": "Image Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 67, "Memory_Usage(MB)": 8003, "Network_Latency(ms)": 16, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 186, "Predicted_Resource_Allocation(%)": 82}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 83.0
# pred: 79.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 189/200
# Context: {"Timestamp": "2024-03-25 14:44:40", "Device_ID": "D15", "Temp": "23°C", "Humidity": "48%", "Workload_Type": "Network Traffic", "Processing_Tier": "Fog", "CPU_Usage(%)": 50, "Memory_Usage(MB)": 1016, "Network_Latency(ms)": 30, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 80, "Predicted_Resource_Allocation(%)": 56}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 52.0
# pred: 55.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 190/200
# Context: {"Timestamp": "2024-03-25 14:44:50", "Device_ID": "D5", "Temp": "30°C", "Humidity": "48%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 53, "Memory_Usage(MB)": 4438, "Network_Latency(ms)": 36, "Network_Jitter(ms)": 3, "Task_Execution_Time(ms)": 152, "Predicted_Resource_Allocation(%)": 72}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 67.0
# pred: 67.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 191/200
# Context: {"Timestamp": "2024-03-25 14:45:00", "Device_ID": "D10", "Temp": "29°C", "Humidity": "57%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 27, "Memory_Usage(MB)": 7518, "Network_Latency(ms)": 17, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 234, "Predicted_Resource_Allocation(%)": 84}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 84.0
# pred: 87.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 192/200
# Context: {"Timestamp": "2024-03-25 14:45:10", "Device_ID": "D15", "Temp": "39°C", "Humidity": "46%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 66, "Memory_Usage(MB)": 3312, "Network_Latency(ms)": 25, "Network_Jitter(ms)": 6, "Task_Execution_Time(ms)": 262, "Predicted_Resource_Allocation(%)": 55}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 58.0
# pred: 57.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 193/200
# Context: {"Timestamp": "2024-03-25 14:45:20", "Device_ID": "D17", "Temp": "22°C", "Humidity": "67%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 80, "Memory_Usage(MB)": 2970, "Network_Latency(ms)": 11, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 114, "Predicted_Resource_Allocation(%)": 81}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 84.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
#
# Question 194/200
# Context: {"Timestamp": "2024-03-25 14:45:30", "Device_ID": "D14", "Temp": "27°C", "Humidity": "43%", "Workload_Type": "Data Analytics", "Processing_Tier": "Cloud", "CPU_Usage(%)": 45, "Memory_Usage(MB)": 4662, "Network_Latency(ms)": 28, "Network_Jitter(ms)": 4, "Task_Execution_Time(ms)": 190, "Predicted_Resource_Allocation(%)": 68}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 64.0
# pred: 69.0
# ❌ Incorrect
# Time taken: 0.03s
# ================================================================================
#
# Question 195/200
# Context: {"Timestamp": "2024-03-25 14:45:40", "Device_ID": "D5", "Temp": "38°C", "Humidity": "63%", "Workload_Type": "Network Traffic", "Processing_Tier": "Device", "CPU_Usage(%)": 85, "Memory_Usage(MB)": 7571, "Network_Latency(ms)": 27, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 242, "Predicted_Resource_Allocation(%)": 66}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 67.0
# pred: 70.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 196/200
# Context: {"Timestamp": "2024-03-25 14:45:50", "Device_ID": "D20", "Temp": "22°C", "Humidity": "70%", "Workload_Type": "Image Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 64, "Memory_Usage(MB)": 3148, "Network_Latency(ms)": 27, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 259, "Predicted_Resource_Allocation(%)": 80}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 83.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 197/200
# Context: {"Timestamp": "2024-03-25 14:46:00", "Device_ID": "D3", "Temp": "20°C", "Humidity": "50%", "Workload_Type": "Image Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 89, "Memory_Usage(MB)": 540, "Network_Latency(ms)": 17, "Network_Jitter(ms)": 1, "Task_Execution_Time(ms)": 114, "Predicted_Resource_Allocation(%)": 60}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 60.0
# pred: 63.0
# ✅ Correct
# Time taken: 0.03s
# ================================================================================
#
# Question 198/200
# Context: {"Timestamp": "2024-03-25 14:46:10", "Device_ID": "D8", "Temp": "34°C", "Humidity": "35%", "Workload_Type": "Video Processing", "Processing_Tier": "Cloud", "CPU_Usage(%)": 43, "Memory_Usage(MB)": 1469, "Network_Latency(ms)": 33, "Network_Jitter(ms)": 2, "Task_Execution_Time(ms)": 207, "Predicted_Resource_Allocation(%)": 86}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 81.0
# pred: 85.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 199/200
# Context: {"Timestamp": "2024-03-25 14:46:20", "Device_ID": "D1", "Temp": "26°C", "Humidity": "61%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 69, "Memory_Usage(MB)": 954, "Network_Latency(ms)": 40, "Network_Jitter(ms)": 9, "Task_Execution_Time(ms)": 282, "Predicted_Resource_Allocation(%)": 84}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 82.0
# pred: 87.0
# ❌ Incorrect
# Time taken: 0.04s
# ================================================================================
#
# Question 200/200
# Context: {"Timestamp": "2024-03-25 14:46:30", "Device_ID": "D2", "Temp": "37°C", "Humidity": "50%", "Workload_Type": "Video Processing", "Processing_Tier": "Device", "CPU_Usage(%)": 78, "Memory_Usage(MB)": 5878, "Network_Latency(ms)": 43, "Network_Jitter(ms)": 8, "Task_Execution_Time(ms)": 223, "Predicted_Resource_Allocation(%)": 56}
# ###
# Predict the Actual Resource Allocation(%)
# y_true: 60.0
# pred: 60.0
# ✅ Correct
# Time taken: 0.04s
# ================================================================================
# Current progress: 200/200, Accuracy: 61.00%
# ================================================================================
# Number of correct answers: 122, Total questions: 200, Accuracy rate: 61.00%, Total runtime: 7.21s (0.00 hours)
